# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

from TrainModelFromGraph import TrainModelFromGraph

# Input variables and config
InputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Graphs_v240725_241106/3neighbours_muonQOverPt/"
OutputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Model_v240725_Bsize64_lr5e-4_NOnormNodes_GAT_241106_v2/"

# %%
# Instantiate the network
trainer = TrainModelFromGraph(graph_path=InputFolder,out_path=OutputFolder,num_files=20)

trainer.load_data()
trainer.plot_graph_features(trainer.train_loader)
trainer.initialize_model()
# Out:
# Loading 20 files
# Total Graphs: 1128585
# Training events: 789568
# ====================================
# Example of data:
# tensor([[1.0331e+00, 1.3951e+00, 1.0060e+03, 6.0000e+00, 9.0000e+00],
#         [1.0114e+00, 1.3881e+00, 1.0767e+03, 1.5000e+01, 5.0000e+00],
#         [1.0440e+00, 1.4044e+00, 1.1959e+03, 7.0000e+00, 9.0000e+00],
#         [1.1092e+00, 1.3614e+00, 4.1368e+02, 1.0000e+01, 5.0000e+00]],
#        dtype=torch.float64)
# tensor([[0, 0, 0, 1, 1, 2, 2, 3],
#         [1, 2, 3, 0, 2, 0, 1, 0]])
# tensor([[-0.0070, -0.0217],
#         [ 0.0093,  0.0109],
#         [-0.0337,  0.0761],
#         [-0.0070, -0.0217],
#         [-0.0163, -0.0326],
#         [ 0.0093,  0.0109],
#         [-0.0163, -0.0326],
#         [-0.0337,  0.0761]])
# tensor([-0.0969])
# ====================================
# Using device: cuda
# Model initialized
# GATRegressor(
#   (conv1): GATConv(5, 64, heads=1)
#   (conv2): GATConv(64, 64, heads=1)
#   (fc1): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
trainer.Training_loop()
# Out:
# Start training...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_524/48204522.py in <module>
# ----> 1 trainer.Training_loop()
#
# /eos/home-i04/f/folguera/L1T/INTREPID/emeleTrigger/tools/training/TrainModelFromGraph.py in Training_loop(self)
#     255         for epoch in range(self.epochs):
#     256             train_loss, train_accuracy = self.train()
# --> 257             test_loss, test_accuracy = self.test()
#     258             train_losses.append(train_loss)
#     259             test_losses.append(test_loss)
#
# /eos/home-i04/f/folguera/L1T/INTREPID/emeleTrigger/tools/training/TrainModelFromGraph.py in test(self)
#     227             total_accuracy = 0
#     228             for data in self.test_loader:
# --> 229                 out = self.model(data)
#     230                 # loss = self.loss_fn(out, data.y.reshape(self.batch_size,3))
#     231                 loss = self.loss_fn(out, data.y.view(out.size()))
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /eos/home-i04/f/folguera/L1T/INTREPID/emeleTrigger/tools/training/models.py in forward(self, data)
#      22         '''
#      23         x = F.relu(x)
# ---> 24         x = self.conv1(x, edge_index, edge_attr=data.edge_attr)
#      25         x = F.relu(x)
#      26         x = self.conv2(x, edge_index, edge_attr=data.edge_attr)
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch_geometric/nn/conv/gat_conv.py in forward(self, x, edge_index, edge_attr, size, return_attention_weights)
#     211         if isinstance(x, Tensor):
#     212             assert x.dim() == 2, "Static graphs not supported in 'GATConv'"
# --> 213             x_src = x_dst = self.lin_src(x).view(-1, H, C)
#     214         else:  # Tuple of source and target node features:
#     215             x_src, x_dst = x
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch_geometric/nn/dense/linear.py in forward(self, x)
#     130             x (torch.Tensor): The input features.
#     131         """
# --> 132         return F.linear(x, self.weight, self.bias)
#     133
#     134     @torch.no_grad()
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_CUDA_mm)
