# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

from TrainModelFromGraph import TrainModelFromGraph

# Input variables and config
InputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Graphs_v240725_241106/3neighbours_muonQOverPt/"
OutputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Model_v240725_Bsize64_lr5e-4_NOnormNodes_GAT_241113/"

# %%
# Instantiate the network
trainer = TrainModelFromGraph(graph_path=InputFolder,out_path=OutputFolder,num_files=20, epochs=100)

trainer.load_data()
trainer.plot_graph_features(trainer.train_loader)
trainer.initialize_model()
# Out:
# Loading 20 files
# Total Graphs: 1128585
# Training events: 789568
# ====================================
# Example of data:
# tensor([[1.0331e+00, 1.3951e+00, 1.0060e+03, 6.0000e+00, 9.0000e+00],
#         [1.0114e+00, 1.3881e+00, 1.0767e+03, 1.5000e+01, 5.0000e+00],
#         [1.0440e+00, 1.4044e+00, 1.1959e+03, 7.0000e+00, 9.0000e+00],
#         [1.1092e+00, 1.3614e+00, 4.1368e+02, 1.0000e+01, 5.0000e+00]],
#        dtype=torch.float64)
# tensor([[0, 0, 0, 1, 1, 2, 2, 3],
#         [1, 2, 3, 0, 2, 0, 1, 0]])
# tensor([[-0.0070, -0.0217],
#         [ 0.0093,  0.0109],
#         [-0.0337,  0.0761],
#         [-0.0070, -0.0217],
#         [-0.0163, -0.0326],
#         [ 0.0093,  0.0109],
#         [-0.0163, -0.0326],
#         [-0.0337,  0.0761]])
# tensor([-0.0969])
# ====================================
# Using device: cuda
# Model initialized
# GATRegressor(
#   (conv1): GATConv(5, 64, heads=1)
#   (conv2): GATConv(64, 64, heads=1)
#   (fc1): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
trainer.Training_loop()
# Out:
# Start training...
# Epoch: 10, Train loss: nan, Test loss: nan, Train accuracy: 0.0000, Test accuracy: 0.0000
# /eos/home-i04/f/folguera/L1T/INTREPID/emeleTrigger/tools/training/TrainModelFromGraph.py:303: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_345/48204522.py in <module>
# ----> 1 trainer.Training_loop()
#
# /eos/home-i04/f/folguera/L1T/INTREPID/emeleTrigger/tools/training/TrainModelFromGraph.py in Training_loop(self)
#     279         train_losses = []
#     280         test_losses = []
# --> 281         train_accuracies = []
#     282         test_accuracies = []
#     283
#
# /eos/home-i04/f/folguera/L1T/INTREPID/emeleTrigger/tools/training/TrainModelFromGraph.py in train(self)
#     239                 print(f"Sending {data.num_graphs} graphd of data to device")
#     240
# --> 241             data = data.to(self.device)  # Mueve los datos al dispositivo
#     242             self.optimizer.zero_grad()
#     243             out = self.model(data)
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# KeyboardInterrupt:
