# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

from TrainModelFromGraph import TrainModelFromGraph

# Input variables and config
#InputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Graphs_v240725_241106/3neighbours_muonQPt/" 
InputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Graphs_v240725_241106/3neighbours_muonQOverPt" #/eos/cms/store/user/folguera/L1TMuon/INTREPID/Graphs_v240725_241113/"
OutputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Model_v240725_Bsize64_lr5e-4_NOnormNodes_muonOverPt_3neight_GAT_241113/"

# %%
# Instantiate the network
trainer = TrainModelFromGraph(graph_path=InputFolder,out_path=OutputFolder,num_files=5, epochs=100,graph_name="vix_graph_6Nov_3")

trainer.load_data()
trainer.plot_graph_features(trainer.train_loader)
trainer.initialize_model()
# Out:
# Loading 5 files
# Total Graphs: 281794
# Training events: 197120
# ...
# Example of data:
# tensor([[1.0331e+00, 1.3951e+00, 1.0060e+03, 6.0000e+00, 9.0000e+00],
#         [1.0114e+00, 1.3881e+00, 1.0767e+03, 1.5000e+01, 5.0000e+00],
#         [1.0440e+00, 1.4044e+00, 1.1959e+03, 7.0000e+00, 9.0000e+00],
#         [1.1092e+00, 1.3614e+00, 4.1368e+02, 1.0000e+01, 5.0000e+00]],
#        dtype=torch.float64)
# tensor([[0, 0, 0, 1, 1, 2, 2, 3],
#         [1, 2, 3, 0, 2, 0, 1, 0]])
# tensor([[-0.0070, -0.0217],
#         [ 0.0093,  0.0109],
#         [-0.0337,  0.0761],
#         [-0.0070, -0.0217],
#         [-0.0163, -0.0326],
#         [ 0.0093,  0.0109],
#         [-0.0163, -0.0326],
#         [-0.0337,  0.0761]])
# tensor([-0.0969])
# ...
# Using device: cuda
# Model initialized
# GATRegressor(
#   (conv1): GATConv(5, 64, heads=1)
#   (conv2): GATConv(64, 64, heads=1)
#   (fc1): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
trainer.Training_loop()
# Out:
# Saving results in /eos/cms/store/user/folguera/L1TMuon/INTREPID/Model_v240725_Bsize64_lr5e-4_NOnormNodes_muonOverPt_3neight_GAT_241113/
# Start training...
# Epoch: 10, Train loss: nan, Test loss: nan, Train accuracy: 0.0000, Test accuracy: 0.0000
# /eos/home-i04/f/folguera/L1T/INTREPID/emeleTrigger/tools/training/TrainModelFromGraph.py:310: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_828/48204522.py", line 1, in <module>
#     trainer.Training_loop()
# ...

# %% [markdown]
# # Now perform the validation

# %%
from TrainModelFromGraph import TrainModelFromGraph

# %%
# Input variables and config
InputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Graphs_v240725_241106/3neighbours_muonQPt/" #/eos/cms/store/user/folguera/L1TMuon/INTREPID/Graphs_v240725_241113/"
OutputFolder = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Model_v240725_Bsize64_lr5e-4_NOnormNodes_muonPt_3neight_GAT_241113/"
ModelPath = "/eos/cms/store/user/folguera/L1TMuon/INTREPID/Model_v240725_Bsize64_lr5e-4_NOnormNodes_muonPt_3neight_GAT_241113/model_100.pth"
OutDir = "Plots_v240725_Bsize64_lr5e-4_NOnormNodes_muonPt_3neight_GAT_241113/"
GraphName = "vix_graph_6Nov_3"


trainer = TrainModelFromGraph(graph_path=InputFolder,model_path=ModelPath,num_files=5, epochs=100,graph_name=GraphName)

# %%
trainer.load_trained_model()
# Out:
# Loading model from /eos/cms/store/user/folguera/L1TMuon/INTREPID/Model_v240725_Bsize64_lr5e-4_NOnormNodes_muonPt_3neight_GAT_241113/model_100.pth

# %%
trainer.load_data()
# Out:
# Loading 5 files
# Total Graphs: 281794
# Training events: 197120
# ...
# Example of data:
# tensor([[1.0331e+00, 1.3951e+00, 1.0060e+03, 6.0000e+00, 9.0000e+00],
#         [1.0114e+00, 1.3881e+00, 1.0767e+03, 1.5000e+01, 5.0000e+00],
#         [1.0440e+00, 1.4044e+00, 1.1959e+03, 7.0000e+00, 9.0000e+00],
#         [1.1092e+00, 1.3614e+00, 4.1368e+02, 1.0000e+01, 5.0000e+00]],
#        dtype=torch.float64)
# tensor([[0, 0, 0, 1, 1, 2, 2, 3],
#         [1, 2, 3, 0, 2, 0, 1, 0]])
# tensor([[-0.0070, -0.0217],
#         [ 0.0093,  0.0109],
#         [-0.0337,  0.0761],
#         [-0.0070, -0.0217],
#         [-0.0163, -0.0326],
#         [ 0.0093,  0.0109],
#         [-0.0163, -0.0326],
#         [-0.0337,  0.0761]])
# tensor([-10.3202])
# ...

# %%
trainer.evaluate()

# %%
trainer.plot_regression(OutDir)
# Out:
# Plotting regression in Plots_v240725_Bsize64_lr5e-4_NOnormNodes_muonPt_3neight_GAT_241113/
# Plotting scatter in Plots_v240725_Bsize64_lr5e-4_NOnormNodes_muonPt_3neight_GAT_241113/
# Plotting difference in Plots_v240725_Bsize64_lr5e-4_NOnormNodes_muonPt_3neight_GAT_241113/
